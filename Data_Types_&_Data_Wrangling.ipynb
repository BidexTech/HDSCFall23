# %% [markdown]
# <a href="https://colab.research.google.com/github/BidexTech/HDSCFall23/blob/main/Data_Types_%26_Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data Types & Data Wrangling
import pandas as pd
csv_df = pd.read_csv('/content/sample_data/california_housing_test.csv')
csv_df
#csv_df.to_csv('sample_file.csv', index=False)

#reading xlsx file
# excel_df = pd.read_excel('sample_file.xlsx')
# excel_df .to_excel('sample_file.xlsx)

##Reading table from a webpage and save as a dataframe
# html_df = pd.read_htlm('http://www.webpage.com/sampledata.html')
# html_df.to_html('sample_file.html')
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
url='https://github.com/WalePhenomenon/climate_change/blob/master/fuel_ferc1.csv?raw=true'
fuel_data = pd.read_csv(url, error_bad_lines=False)
fuel_data.describe(include='all')
# Out:
# <ipython-input-2-6c798e6eefab>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   fuel_data = pd.read_csv(url, error_bad_lines=False)
#                     record_id  utility_id_ferc1   report_year  \
# count                   29523      29523.000000  29523.000000
# unique                  29523               NaN           NaN
# top     f1_fuel_1994_12_1_0_7               NaN           NaN
# freq                        1               NaN           NaN
# mean                      NaN        118.601836   2005.806050
# std                       NaN         74.178353      7.025483
# min                       NaN          1.000000   1994.000000
# 25%                       NaN         55.000000   2000.000000
# 50%                       NaN        122.000000   2006.000000
# 75%                       NaN        176.000000   2012.000000
# ...

# %%
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
#checking for missing value
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
fuel_data[['fuel_unit']]= fuel_data[['fuel_unit']].fillna(value='mcf')

# %%
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11534
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
fuel_data.groupby('report_year')['report_year'].count()
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
fuel_data.groupby('fuel_type_code_pudl').first()
# Out:
#                                   record_id  utility_id_ferc1  report_year  \
# fuel_type_code_pudl
# coal                  f1_fuel_1994_12_1_0_7                 1         1994
# gas                  f1_fuel_1994_12_2_0_10                 2         1994
# nuclear               f1_fuel_1994_12_2_1_1                 2         1994
# oil                   f1_fuel_1994_12_6_0_2                 6         1994
# other                f1_fuel_1994_12_11_0_6                11         1994
# waste                 f1_fuel_1994_12_9_0_3                 9         1994
#
#                      plant_name_ferc1 fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                         rockport       ton        5377489.0
# gas                         chickasaw       mcf          40533.0
# nuclear              joseph m. farley       kgU           2260.0
# oil                      clinch river       bbl           6510.0
# other                      w.f. wyman       bbl          55652.0
# ...

# %% [markdown]
# #merging in pandas

# %%
fuel_df1 = fuel_data.iloc[0:19000].reset_index(drop=True)
fuel_df2 = fuel_data.iloc[19000:].reset_index(drop=True)

# %%
fuel_df1
fuel_df2
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_2009_12_79_0_2                79         2009
# 1       f1_fuel_2009_12_79_0_4                79         2009
# 2       f1_fuel_2009_12_79_0_5                79         2009
# 3       f1_fuel_2009_12_79_0_7                79         2009
# 4      f1_fuel_2009_12_79_0_10                79         2009
# ...                        ...               ...          ...
# 10518  f1_fuel_2018_12_12_0_13                12         2018
# 10519   f1_fuel_2018_12_12_1_1                12         2018
# 10520  f1_fuel_2018_12_12_1_10                12         2018
# 10521  f1_fuel_2018_12_12_1_13                12         2018
# 10522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  montrose                 oil       bbl          22912.0
# ...

# %%
#checking length of both data frames sum to the expected length
assert len(fuel_data) == (len(fuel_df1) + len(fuel_df2))

# %%
#an inner merge will lose rows that do not match in both dataframes
pd.merge(fuel_df1, fuel_df2, how="inner")
# Out:
# Empty DataFrame
# Columns: [record_id, utility_id_ferc1, report_year, plant_name_ferc1, fuel_type_code_pudl, fuel_unit, fuel_qty_burned, fuel_mmbtu_per_unit, fuel_cost_per_unit_burned, fuel_cost_per_unit_delivered, fuel_cost_per_mmbtu]
# Index: []

# %%
#outer merge returns all rows in both dataframes
pd.merge(fuel_df1, fuel_df2, how="outer")
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
#left merge removes rows from the right dataframe that do not have a match with the left
#and keeps all rows from the left
pd.merge(fuel_df1, fuel_df2, how="left")
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# ...                         ...               ...          ...
# 18995   f1_fuel_2009_12_182_1_9               182         2009
# 18996  f1_fuel_2009_12_182_1_10               182         2009
# 18997  f1_fuel_2009_12_182_1_13               182         2009
# 18998  f1_fuel_2009_12_182_1_14               182         2009
# 18999    f1_fuel_2009_12_79_0_1                79         2009
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
#Right merge removes rows from the left dataframe that do not have a match with the Right
#and keeps all rows from the Right
pd.merge(fuel_df1, fuel_df2, how="right")
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_2009_12_79_0_2                79         2009
# 1       f1_fuel_2009_12_79_0_4                79         2009
# 2       f1_fuel_2009_12_79_0_5                79         2009
# 3       f1_fuel_2009_12_79_0_7                79         2009
# 4      f1_fuel_2009_12_79_0_10                79         2009
# ...                        ...               ...          ...
# 10518  f1_fuel_2018_12_12_0_13                12         2018
# 10519   f1_fuel_2018_12_12_1_1                12         2018
# 10520  f1_fuel_2018_12_12_1_10                12         2018
# 10521  f1_fuel_2018_12_12_1_13                12         2018
# 10522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  montrose                 oil       bbl          22912.0
# ...

# %%
#concatenate
pd.concat([fuel_data, data_to_concat]).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-39da32cd7b09> in <cell line: 2>()
#       1 #concatenate
# ----> 2 pd.concat([fuel_data, data_to_concat]).reset_index(drop=True)
#
# NameError: name 'data_to_concat' is not defined

# %%
#check for duplicate rows
fuel_data.duplicated().any()
# Out:
# False

# %% [markdown]
# #:Data Visualization and Representation in Python

# %%
#import plotting library
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU','MCF', 'MMBTU','MWDTH','MWHTH', 'TON'],
                          'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
sns.barplot(data=fuel_unit, x='unit', y='count')
plt.xlabel('Fuel unit')
# Out:
# Text(0.5, 0, 'Fuel unit')

# %%
g=sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale('log')
g.set_ylim(1, 1200)
plt.xlabel('Fuel unit')
# Out:
# Text(0.5, 0, 'Fuel unit')
